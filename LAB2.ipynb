# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriyam7569/UCS-420/blob/main/LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=float(input("Enter your first number:"))
b=float(input("Enter your second number:"))
if a>b:
  print ("first number is greater than second number")
elif a<b:
  print ("first number is less than second number")
else:
  print ("first number is equal to second number")
# Out:
# Enter your first number:7
# Enter your second number:9
# first number is less than second number

# %%
a = float(input("Enter your first number: "))
b = float(input("Enter your second number: "))
c = float(input("Enter your third number: "))

if a > b and a > c:
    print("first number is greatest")
elif b > a and b > c:
    print("second number is greatest")
else:
    print("third number is greatest")
# Out:
# Enter your first number: 4
# Enter your second number: 5
# Enter your third number: 6
# third number is greatest

# %%
a = float(input("Enter your first number: "))
b = float(input("Enter your second number: "))
c = float(input("Enter your third number: "))
max(a,b,c)
# Out:
# Enter your first number: 5
# Enter your second number: 6
# Enter your third number: 7
# 7.0

# %%
n = int(input("Enter a number: "))
s = 0

for i in range(1, n+1):
    if i % 9 == 0 and i % 9 == 0:
        s = s + i

print("s =", s)
# Out:
# Enter a number: 333333
# s = 6172993827

# %%
n = int(input("Enter a number: "))
count = 0

for i in range(2, n + 1): count = 0

for j in range(2, i):
    if i % j == 0:
        count = count + 1

if count == 0:
    s = s + i
print("Sum of prime numbers =", s)
# Out:
# Enter a number: 655
# Sum of prime numbers = 361803492

# %%
def ADD(a, b):
    c = a + b
    return c

print(ADD(5, 10))
# Out:
# 15

# %%
print("hi")
# Out:
# hi

# %%
def odd(n):
  for i in range (1,n+1):
    if i%2!=0:
      print(i)

odd(8)
# Out:
# Enter your number: 7
# 1
# 3
# 5
# 7
